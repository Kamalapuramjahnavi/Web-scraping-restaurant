# %% [markdown]
# # Problem Statement: Develop the scraper to scrape Grab Food Delivery

# %% [markdown]
# Writing a web Scraping code:

# %%
# Import necessary modules

# 1. requests: This library is used to send HTTP requests in Python. 
#In this code, it's used to make GET requests to fetch HTML content from the GrabFood website. 
#The `get` function from the `requests` module is used to perform these HTTP GET requests.

# 2. BeautifulSoup: BeautifulSoup is a Python library used for web scraping. 
# It facilitates parsing HTML and XML documents, extracting useful data, and navigating through the document tree. 
# In this code, BeautifulSoup is used to parse the HTML content retrieved from the GrabFood website, making it easier to 
# extract specific information such as restaurant names, cuisines, ratings, and delivery times.

# 3. threading: Threading is a built-in Python module used for working with threads. 
# Threads allow concurrent execution of tasks, which can improve performance in certain scenarios, such as web scraping. 
# In this code, threading is used to scrape multiple restaurants simultaneously, making the scraping process faster. 
# The `Thread` class from the `threading` module is used to create new threads, and the `start` and `join` methods are used to 
# start and synchronize the execution of threads, respectively.

# These libraries provide essential functionality for web scraping and concurrent execution of tasks, enabling efficient 
# retrieval of restaurant information from the GrabFood website.

import requests
from bs4 import BeautifulSoup
import threading
import csv 
import pandas as pd

# Define the user-agent header
HEADERS = {'User-Agent': 'Mozilla/5.0 (iPad; CPU OS 12_2 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Mobile/15E148'}
# Define the base URL of the website
BASE_URL = "https://food.grab.com"

# Function to scrape individual restaurant information
def scrape_restaurant_info(url):
    # Print a debug message indicating which restaurant info is being scraped
    print(f"Scraping restaurant info for: {url}")
    # Send a GET request to the restaurant URL
    r = requests.get(BASE_URL + url, headers=HEADERS)
    # Parse the HTML content of the response
    soup = BeautifulSoup(r.content, 'html.parser')
    # Extract relevant information about the restaurant
    out = True
    try:
        aa = soup.find("h1", {"class": ["name___1Ls94"]}).text
        bb = soup.find("h3", {"class": ["cuisine___3sorn", "infoRow___3TzCZ"]}).text
        cc = soup.find("div", {"class": ["rating___1ZywF"]}).find('div').text
        dd = soup.find("div", {"class": ["distance___3UWcK"]}).find('div').text
    except:
        out = False
        pass
    ee= soup.findAll("div",{"class":["category___3C8lX"],"id":["Promotions_SGCAT20231030020149015078"]})
    zz= soup.findAll("div",{"class":["promoName___2qJQm"]})
    promotions = []
    for ee_ in ee:
        ss = ee_.findAll("div",{"class":"menuItemWrapper___1xIAB"})
        for ss_ in ss:
            a,b,c = None , None , None
            kk =ss_.find("div",{"class":"ant-row menuItemInfo___PyfMY"})
            try:
                a = kk.find("p",{"class":["itemNameTitle___1sFBq"]}).text

                b = kk.find("p",{"class":["itemDescription___2cIzt"]}).text

                c = kk.find("h6",{"class":["discountedPrice___3MBVA"]}).text
            except:
                pass
            print(a,b,c)
            promotions.append([a,b,c])
            def get_lat_long(address):
                base_url = "https://food.grab.com"
                params = {
                    'q': address,
                    'format': 'json',
                }
                response = requests.get(base_url, params=params)
                if response.status_code == 200:
                    data = response.json()
                    if data:
                        latitude = data[0]['lat']
                        longitude = data[0]['lon']
                        return latitude, longitude
                    else:
                        return None, None
                else:
                    print("Failed to fetch coordinates:", response.status_code)
                    return None, None
    
            # Get latitude and longitude for the restaurant's address
            latitude, longitude = get_lat_long(dd)
    
    try:
        # Print the extracted information
        print('=' * 100)
        print(f"Name: {aa}")
        print(f"Cuisine: {bb}")
        print(f"Rating: {cc}")
        print(f"Delivery Time: {dd}")
        z_res = None
        if len(zz)>=2:
            z_res = zz[1].text
            print(f"Delivery Fee: ",zz[1].text)
    except:
        out = False
        pass
    if out is True:
        with open("out.csv", 'a') as csvfile:
            # creating a csv writer object
            csvwriter = csv.writer(csvfile)
            # writing the fields
            csvwriter.writerow([aa,bb,cc,dd ,z_res, promotions])

# Function to scrape restaurants from a list of URLs
threads = []
def scrape_restaurants(urls):
    print(urls)

    if True:
        # Iterate over each restaurant element
        for url in urls:
            # Find the anchor tag containing the restaurant URL
            #c = restaurant.find('a', href=True)
            # If the anchor tag is found
            if True:
                # Create a new thread to scrape restaurant info
                thread = threading.Thread(target=scrape_restaurant_info, args=(url,))
                # Add the thread to the list
                threads.append(thread)
                # Start the thread
                thread.start()
                # Print a debug message indicating the thread is started
                print(f"Thread started for: {url}")

# Main function to orchestrate the scraping process
def main():
    # URL of the main page containing restaurant links
    url = "/sg/en/restaurants"
    # Send a GET request to the main page
    r = requests.get(BASE_URL + url, headers=HEADERS)
    # Parse the HTML content of the response
    soup = BeautifulSoup(r.content, 'html.parser')
    # Find all elements containing restaurant information
    b = soup.find_all(class_=["ant-col-24 RestaurantListCol___1FZ8V", "ant-col-md-12", "ant-col-lg-6"])
    # Scrape restaurant information from the list of URLs
    scrape_restaurants([restaurant.find('a', href=True)["href"] for restaurant in b if restaurant.find('a', href=True)])
    
    
# Entry point of the script
if __name__ == "__main__":
    main()
# Out:
# ['/sg/en/restaurant/dapur-penyet-north-bridge-road-delivery/4-C6EFRUMTJU2JBA?', '/sg/en/restaurant/mcdonald-s-boat-quay-delivery/SGDD04944?', '/sg/en/restaurant/wok-hey-funan-delivery/4-C2VKJ3U2C2JZTN?', '/sg/en/restaurant/koi-th%C3%A9-funan-delivery/4-C4NJGEDEE2X1TN?', '/sg/en/restaurant/tandoori-zaika-70-boat-quay-delivery/4-CZD3LRMAWEKVLJ?', '/sg/en/restaurant/stuff-d-funan-delivery/4-C2VKLAC2MBT2NJ?', '/sg/en/restaurant/liho-tea-funan-delivery/4-CZCBCGNXAY5ACA?', '/sg/en/restaurant/sanook-kitchen-funan-mall-delivery/4-C2E3GCCFEEWXAN?', '/sg/en/restaurant/subway-funan-delivery/4-CZDKG25AVYVAT6?', '/sg/en/restaurant/paradise-dynasty-funan-delivery/4-CYUTT6CDRUXXL6?', '/sg/en/restaurant/ramen-matsuri-7-north-canal-road-delivery/SGDD00979?', '/sg/en/restaurant/briyani-hut-boat-quay-delivery/4-C32KFE3EFB31T2?', '/sg/en/restaurant/guzman-y-gomez-funan-delivery/4-CZEUR7LAUCDEC2?', '/sg/en/restaurant/sukiya-funan-delivery/4-C3XTAN6WCCLJKA?', '/sg/en/restaurant/authentic-hock-lam-beef-noodles-13-north-canal-road-delivery/SGDD01360?', '/sg/en/restaurant/the-penny-black-victorian-london-pub-boat-quay-delivery/4-C2WVTE2WRN4WVT?', '/sg/en/restaurant/kebabs-faktory-funan-delivery/4-CZAWBCC1SEVYEA?', '/sg/en/restaurant/legendary-bak-kut-teh-south-bridge-road-delivery/4-C2DJCGCKVN63J6?', '/sg/en/restaurant/saap-saap-thai-funan-delivery/4-CYWCATD3GAWTRN?', '/sg/en/restaurant/wingstop-funan-delivery/4-C4NBJNMVAYXZME?', '/sg/en/restaurant/lucky-cafe-north-canal-road-delivery/4-CZDWARLXDBJYKE?', '/sg/en/restaurant/ps-cafe-one-fullerton-delivery/SGDD08719?', '/sg/en/restaurant/yan-ji-gourmet-seafood-soup-funan-delivery/4-CYU2V2KFCGLXTJ?', '/sg/en/restaurant/smile-martabak-funan-delivery/4-C3KBLATWN8L1TN?', '/sg/en/restaurant/ajumma-s-funan-delivery/4-CZEXGY4XWGNBTE?', '/sg/en/restaurant/lenu-noodle-bar-funan-delivery/4-CYUTT6CDJ4ETNT?', '/sg/en/restaurant/mr-tandoor-boat-quay-delivery/4-C32KFE3EET3HAX?', '/sg/en/restaurant/sf-fruits-juices-fullerton-waterboat-house-delivery/4-C4MDVPMAFGAJUE?', '/sg/en/restaurant/qi-ji-funan-mall-delivery/4-CYWKAUBUPEDVJX?', '/sg/en/restaurant/harry-s-boat-quay-delivery/SGDD06424?', '/sg/en/restaurant/gyo-gyo-funan-delivery/4-C3NZSEWUCBVBAT?']
# Scraping restaurant info for: /sg/en/restaurant/dapur-penyet-north-bridge-road-delivery/4-C6EFRUMTJU2JBA?
# Thread started for: /sg/en/restaurant/dapur-penyet-north-bridge-road-delivery/4-C6EFRUMTJU2JBA?
# Scraping restaurant info for: /sg/en/restaurant/mcdonald-s-boat-quay-delivery/SGDD04944?Thread started for: /sg/en/restaurant/mcdonald-s-boat-quay-delivery/SGDD04944?
#
# Scraping restaurant info for: /sg/en/restaurant/wok-hey-funan-delivery/4-C2VKJ3U2C2JZTN?Thread started for: /sg/en/restaurant/wok-hey-funan-delivery/4-C2VKJ3U2C2JZTN?
#
# Scraping restaurant info for: /sg/en/restaurant/koi-th%C3%A9-funan-delivery/4-C4NJGEDEE2X1TN?
# Thread started for: /sg/en/restaurant/koi-th%C3%A9-funan-delivery/4-C4NJGEDEE2X1TN?
# Scraping restaurant info for: /sg/en/restaurant/tandoori-zaika-70-boat-quay-delivery/4-CZD3LRMAWEKVLJ?Thread started for: /sg/en/restaurant/tandoori-zaika-70-boat-quay-delivery/4-CZD3LRMAWEKVLJ?
#
# Scraping restaurant info for: /sg/en/restaurant/stuff-d-funan-delivery/4-C2VKLAC2MBT2NJ?Thread started for: /sg/en/restaurant/stuff-d-funan-delivery/4-C2VKLAC2MBT2NJ?
#
# Scraping restaurant info for: /sg/en/restaurant/liho-tea-funan-delivery/4-CZCBCGNXAY5ACA?
# Thread started for: /sg/en/restaurant/liho-tea-funan-delivery/4-CZCBCGNXAY5ACA?
# Scraping restaurant info for: /sg/en/restaurant/sanook-kitchen-funan-mall-delivery/4-C2E3GCCFEEWXAN?Thread started for: /sg/en/restaurant/sanook-kitchen-funan-mall-delivery/4-C2E3GCCFEEWXAN?
# Scraping restaurant info for: /sg/en/restaurant/subway-funan-delivery/4-CZDKG25AVYVAT6?
# Thread started for: /sg/en/restaurant/subway-funan-delivery/4-CZDKG25AVYVAT6?
#
# Scraping restaurant info for: /sg/en/restaurant/paradise-dynasty-funan-delivery/4-CYUTT6CDRUXXL6?
# Thread started for: /sg/en/restaurant/paradise-dynasty-funan-delivery/4-CYUTT6CDRUXXL6?
# Scraping restaurant info for: /sg/en/restaurant/ramen-matsuri-7-north-canal-road-delivery/SGDD00979?
# Thread started for: /sg/en/restaurant/ramen-matsuri-7-north-canal-road-delivery/SGDD00979?
# Scraping restaurant info for: /sg/en/restaurant/briyani-hut-boat-quay-delivery/4-C32KFE3EFB31T2?Thread started for: /sg/en/restaurant/briyani-hut-boat-quay-delivery/4-C32KFE3EFB31T2?
#
# Scraping restaurant info for: /sg/en/restaurant/guzman-y-gomez-funan-delivery/4-CZEUR7LAUCDEC2?Thread started for: /sg/en/restaurant/guzman-y-gomez-funan-delivery/4-CZEUR7LAUCDEC2?
#
# Scraping restaurant info for: /sg/en/restaurant/sukiya-funan-delivery/4-C3XTAN6WCCLJKA?
# Thread started for: /sg/en/restaurant/sukiya-funan-delivery/4-C3XTAN6WCCLJKA?
# Scraping restaurant info for: /sg/en/restaurant/authentic-hock-lam-beef-noodles-13-north-canal-road-delivery/SGDD01360?Thread started for: /sg/en/restaurant/authentic-hock-lam-beef-noodles-13-north-canal-road-delivery/SGDD01360?
#
# Scraping restaurant info for: /sg/en/restaurant/the-penny-black-victorian-london-pub-boat-quay-delivery/4-C2WVTE2WRN4WVT?Thread started for: /sg/en/restaurant/the-penny-black-victorian-london-pub-boat-quay-delivery/4-C2WVTE2WRN4WVT?
#
# Scraping restaurant info for: /sg/en/restaurant/kebabs-faktory-funan-delivery/4-CZAWBCC1SEVYEA?
# Thread started for: /sg/en/restaurant/kebabs-faktory-funan-delivery/4-CZAWBCC1SEVYEA?
# Scraping restaurant info for: /sg/en/restaurant/legendary-bak-kut-teh-south-bridge-road-delivery/4-C2DJCGCKVN63J6?Thread started for: /sg/en/restaurant/legendary-bak-kut-teh-south-bridge-road-delivery/4-C2DJCGCKVN63J6?
#
# Scraping restaurant info for: /sg/en/restaurant/saap-saap-thai-funan-delivery/4-CYWCATD3GAWTRN?
# Thread started for: /sg/en/restaurant/saap-saap-thai-funan-delivery/4-CYWCATD3GAWTRN?
# Scraping restaurant info for: /sg/en/restaurant/wingstop-funan-delivery/4-C4NBJNMVAYXZME?Thread started for: /sg/en/restaurant/wingstop-funan-delivery/4-C4NBJNMVAYXZME?
#
# Scraping restaurant info for: /sg/en/restaurant/lucky-cafe-north-canal-road-delivery/4-CZDWARLXDBJYKE?
# Thread started for: /sg/en/restaurant/lucky-cafe-north-canal-road-delivery/4-CZDWARLXDBJYKE?
# Scraping restaurant info for: /sg/en/restaurant/ps-cafe-one-fullerton-delivery/SGDD08719?
# Thread started for: /sg/en/restaurant/ps-cafe-one-fullerton-delivery/SGDD08719?
# Scraping restaurant info for: /sg/en/restaurant/yan-ji-gourmet-seafood-soup-funan-delivery/4-CYU2V2KFCGLXTJ?
# Thread started for: /sg/en/restaurant/yan-ji-gourmet-seafood-soup-funan-delivery/4-CYU2V2KFCGLXTJ?
# Scraping restaurant info for: /sg/en/restaurant/smile-martabak-funan-delivery/4-C3KBLATWN8L1TN?
# Thread started for: /sg/en/restaurant/smile-martabak-funan-delivery/4-C3KBLATWN8L1TN?
# Scraping restaurant info for: /sg/en/restaurant/ajumma-s-funan-delivery/4-CZEXGY4XWGNBTE?Thread started for: /sg/en/restaurant/ajumma-s-funan-delivery/4-CZEXGY4XWGNBTE?
#
# Scraping restaurant info for: /sg/en/restaurant/lenu-noodle-bar-funan-delivery/4-CYUTT6CDJ4ETNT?Thread started for: /sg/en/restaurant/lenu-noodle-bar-funan-delivery/4-CYUTT6CDJ4ETNT?
#
# Scraping restaurant info for: /sg/en/restaurant/mr-tandoor-boat-quay-delivery/4-C32KFE3EET3HAX?Thread started for: /sg/en/restaurant/mr-tandoor-boat-quay-delivery/4-C32KFE3EET3HAX?
#
# Scraping restaurant info for: /sg/en/restaurant/sf-fruits-juices-fullerton-waterboat-house-delivery/4-C4MDVPMAFGAJUE?Thread started for: /sg/en/restaurant/sf-fruits-juices-fullerton-waterboat-house-delivery/4-C4MDVPMAFGAJUE?
#
# Scraping restaurant info for: /sg/en/restaurant/qi-ji-funan-mall-delivery/4-CYWKAUBUPEDVJX?
# Thread started for: /sg/en/restaurant/qi-ji-funan-mall-delivery/4-CYWKAUBUPEDVJX?
# Scraping restaurant info for: /sg/en/restaurant/harry-s-boat-quay-delivery/SGDD06424?Thread started for: /sg/en/restaurant/harry-s-boat-quay-delivery/SGDD06424?
#
# Scraping restaurant info for: /sg/en/restaurant/gyo-gyo-funan-delivery/4-C3NZSEWUCBVBAT?Thread started for: /sg/en/restaurant/gyo-gyo-funan-delivery/4-C3NZSEWUCBVBAT?
#
# ====================================================================================================
# Name: WOK HEY - Funan
# Cuisine: Bento,Chinese,Local & Malaysian,Halal,Group Friendly
# Rating: 4.4
# Delivery Time: 35 mins  •  0.9 km
# ====================================================================================================
# ====================================================================================================
# ====================================================================================================
# ============================================================================================================================================================================================================================================================================================================
#
#
# ====================================================================================================
# ====================================================================================================
# ========================================================================================================================================================================================================
# ====================================================================================================
# ====================================================================================================
# Name: Dapur Penyet - North Bridge Road
# Cuisine: Indonesian,Halal,Seafood
# Rating: 4.2
# Delivery Time: 45 mins  •  0.5 km
#
# ====================================================================================================
# ====================================================================================================
# ================================================================================================================================================================================================================================================================================================================================================================================================================
#
#
#
# ========================================================================================================================================================================================================
#
# Name: Authentic Hock Lam Beef Noodles - 13 North Canal Road
# Cuisine: Chinese,NoodlesName: KOI Thé - Funan
# Rating: 4.6
# Delivery Time: 40 mins  •  1.4 km
#
# ========================================================================================================================================================================================================
# Cuisine: Bubble Tea,Coffee & Tea,Drinks & Beverages
# Name: Ramen Matsuri - 7 North Canal Road
# Cuisine: Japanese,Ramen,NoodlesName: LiHO TEA - Funan====================================================================================================
# Rating: 4.7
#
#
# Rating: 4.6
# Delivery Time: 40 mins  •  1.3 kmDelivery Time: 40 mins  •  0.5 km
#
# Cuisine: Coffee & Tea,Drinks & Beverages,Bubble Tea,Group Friendly
# Rating: 4.5
# Delivery Time: 35 mins  •  0.9 km
#
# Name: Stuff'd - Funan
# Cuisine: Healthy,Salad,Mexican,Halal,Group Friendly
# Rating: 4.3
# Delivery Time: 35 mins  •  0.5 km
# ====================================================================================================
# ====================================================================================================
# Name: Sanook Kitchen - Funan Mall
# Cuisine: Thai
# Rating: 4.3
# Delivery Time: 45 mins  •  0.9 km
# Name: Guzman Y Gomez - Funan
# Cuisine: Mexican,Kids Friendly,Healthy,Group Friendly
# Rating: 4.2
# Delivery Time: 45 mins  •  0.9 km
# ====================================================================================================
# Name: Tandoori Zaika - 70 Boat Quay
# Cuisine: Indian,Salad,Seafood,Vegetarian Friendly
# Rating: 4.3
# Delivery Time: 65 mins  •  1.2 km
# ====================================================================================================
# Name: Sukiya - Funan
# Cuisine: Japanese,Kids Friendly,Drinks & Beverages,Seafood,Halal
# Rating: 4.3
# Delivery Time: 35 mins  •  0.5 km
# ====================================================================================================
# Name: Paradise Dynasty - Funan
# Cuisine: Chinese,Noodles,Rice
# Rating: 4.6
# Delivery Time: 40 mins  •  0.9 km
# ====================================================================================================
# Name: McDonald's - Boat Quay
# Cuisine: Burger,Fast Food,Halal
# Rating: 4.2
# Delivery Time: 30 mins  •  1.6 km
# ====================================================================================================
# Name: Subway - Funan
# Cuisine: Sandwiches,Halal,Fast Food,Group Friendly
# Rating: 4.4
# Delivery Time: 35 mins  •  0.5 km

# %%
import csv
import json

csvfile = open('out.csv', 'r')
jsonfile = open('out.ndjson', 'w')

fieldnames = ("Name","Cuisine","Rating","Delivery Time","Delivery Fee")
reader = csv.DictReader( csvfile, fieldnames)
for row in reader:
    json.dump(row, jsonfile)
    jsonfile.write('\n')
